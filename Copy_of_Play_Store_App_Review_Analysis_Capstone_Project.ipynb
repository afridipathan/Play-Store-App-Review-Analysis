# %% [markdown]
# <a href="https://colab.research.google.com/github/afridipathan/Play-Store-App-Review-Analysis/blob/main/Copy_of_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# # Google Play Store Apps Data Analysis (EDA)**bold text**

# %% [markdown]
# # **Objective of project**
# The objective of this project to deliver insight and better understand user and developer through the many data operation and understand better customer demands to populrize the Applications

# %% [markdown]
# # **Used Libraries**
# NumPy (Numerical Python)
# Pandas
# Matplotlib
# Seaborn
# Word Cloud

# %% [markdown]
# # **Lets Import Data**

# %%
# Let us begin with importing the libraries
import pandas as pd # linear algebra
import numpy as np # data processing
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# %%
#mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read the data files
play_store = pd.read_csv("/content/drive/MyDrive/Play Store Data.csv")
user_review = pd.read_csv("/content/drive/MyDrive/User Reviews.csv")

# %% [markdown]
# # **Lets Play The Two DataSet**

# %%
#lets print shape of the two dataset
print(f"the play store dataset shape is{play_store.shape}")
print(f"the user review dataset shape is{user_review.shape}")
# Out:
# the play store dataset shape is(10841, 13)
# the user review dataset shape is(64295, 5)

# %% [markdown]
# # **Cleaning the data both dataframe(play store And user review)**

# %% [markdown]
# **1 Play store data**

# %%
#The Head is show the first 5 row on the dataset
play_store.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#The tail is show the last 5 row on the dataset
play_store.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
#concate head and tail data
pd.concat([play_store.head(5),play_store.tail(5)])
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# ...

# %%
# The info shows the non null valu counts,data type and shape of the data in dataset
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# In Play store dataset 10841 rows and 13 column

# %%
#play store data column name
play_store.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# fill the '_' with space for ease to use column name in play store data
play_store.columns.str.replace(" ","_")
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Current_Ver',
#        'Android_Ver'],
#       dtype='object')

# %%
# play store data describe
play_store.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# #

# %%
#Let's check the no of NaN value present in each column
NaN_Checker = pd.DataFrame({"No Of Total Values":play_store.shape[0] , "No of NaN values":play_store.isnull().sum(),
                    "%age of NaN values" : round((play_store.isnull().sum()  /play_store.shape[0])*100,4) })
NaN_Checker.sort_values("No of NaN values" , ascending = False)
# Out:
#                 No Of Total Values  No of NaN values  %age of NaN values
# Rating                       10841              1474             13.5965
# Current Ver                  10841                 8              0.0738
# Android Ver                  10841                 3              0.0277
# Type                         10841                 1              0.0092
# Content Rating               10841                 1              0.0092
# App                          10841                 0              0.0000
# Category                     10841                 0              0.0000
# Reviews                      10841                 0              0.0000
# Size                         10841                 0              0.0000
# Installs                     10841                 0              0.0000
# Price                        10841                 0              0.0000
# Genres                       10841                 0              0.0000
# ...

# %% [markdown]
# you can see the rating column highest number of nan values

# %% [markdown]
# # **SIZE**

# %% [markdown]
# Convert size column string to float

# %%
type(play_store.Size.iloc[0][1])
# Out:
# str

# %%
play_store['Size'] = play_store['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
play_store['Size'] = play_store['Size'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else x)
play_store['Size'] = play_store['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
play_store['Size'] = play_store['Size'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else x)
play_store['Size'] = play_store['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
play_store['Size'] = play_store['Size'].apply(lambda x: float(x))

# %%
play_store[['Size']].head(5)
# Out:
#    Size
# 0  19.0
# 1  14.0
# 2   8.7
# 3  25.0
# 4   2.8

# %%
play_store[['Size']].tail()
# Out:
#        Size
# 10836  53.0
# 10837   3.6
# 10838   9.5
# 10839   NaN
# 10840  19.0

# %%
#after convert Size str to numerical
type(play_store.Size.iloc[0])
# Out:
# numpy.float64

# %% [markdown]
# # **INSTALLS**

# %%
type(play_store.Installs.iloc[0][1])
# Out:
# str

# %%
#lets convert install str to numerical
play_store[play_store.Installs=="Free"]
play_store.drop(play_store.index[10472], inplace=True)
play_store['Installs'] = play_store['Installs'].map(lambda x: x.replace('+' , ""))
play_store['Installs'] = pd.to_numeric(play_store['Installs'].str.replace(',',''))

# %%
play_store[['Installs']].head()
# Out:
#    Installs
# 0     10000
# 1    500000
# 2   5000000
# 3  50000000
# 4    100000

# %%
#after convert installs str to numerical
type(play_store.Installs.iloc[0])
# Out:
# numpy.int64

# %% [markdown]
# # **Log_installs**

# %%
play_store['Log_installs'] = np.log2( play_store['Installs'])
play_store[['Installs' , 'Log_installs' ]].head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Installs  Log_installs
# 0     10000     13.287712
# 1    500000     18.931569

# %% [markdown]
# # **Drop nan value**

# %%
print("Before dropping the NaN values shape was :- ",play_store.shape)
play_store.dropna( inplace = True )
print("After dropping the NaN values shape is :- ",play_store.shape)
# Out:
# Before dropping the NaN values shape was :-  (10840, 14)
# After dropping the NaN values shape is :-  (7723, 14)

# %% [markdown]
# # **Check nan value**

# %%
NaN_Checker = pd.DataFrame({"No Of Total Values": play_store.shape[0] , "No of NaN values":play_store.isnull().sum(),
                    "%age of NaN values" : round((play_store.isnull().sum()/play_store.shape[0])*100 , 2) })
NaN_Checker.sort_values("No of NaN values" , ascending = False)
# Out:
#                 No Of Total Values  No of NaN values  %age of NaN values
# App                           7723                 0                 0.0
# Category                      7723                 0                 0.0
# Rating                        7723                 0                 0.0
# Reviews                       7723                 0                 0.0
# Size                          7723                 0                 0.0
# Installs                      7723                 0                 0.0
# Type                          7723                 0                 0.0
# Price                         7723                 0                 0.0
# Content Rating                7723                 0                 0.0
# Genres                        7723                 0                 0.0
# Last Updated                  7723                 0                 0.0
# Current Ver                   7723                 0                 0.0
# ...

# %% [markdown]
# I have cleaned & converted numerical columns(Installs) to numrical column

# %% [markdown]
# # **Check Duplicate value**

# %%
#check Duplicate value from same app name
play_store['App'].duplicated().sum()
# Out:
# 700

# %%
play_store['App'].value_counts()
# Out:
# ROBLOX                                           9
# Candy Crush Saga                                 7
# 8 Ball Pool                                      7
# Subway Surfers                                   6
# Temple Run 2                                     6
#                                                 ..
# S Launcher for Galaxy TouchWiz                   1
# R. Lee Ermey's Official Sound                    1
# Neon-R (Red)                                     1
# Wonder5 Masters R                                1
# iHoroscope - 2018 Daily Horoscope & Astrology    1
# Name: App, Length: 7023, dtype: int64

# %%
play_store[ play_store['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews  Size   Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67.0  100000000  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67.0  100000000  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67.0  100000000  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67.0  100000000  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67.0  100000000  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67.0  100000000  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67.0  100000000  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67.0  100000000  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67.0  100000000  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# ...

# %%
play_store.drop_duplicates(subset=['App','Category'],inplace=True)

# %%
play_store['App'].duplicated().any()
# Out:
# True

# %%
play_store[play_store['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews  Size   Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67.0  100000000  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67.0  100000000  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2016   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver  Log_installs
# 1653  2.347.225742  4.1 and up     26.575425
# 2016  2.347.225742  4.1 and up     26.575425

# %% [markdown]
# # Now we have sucsessfully remove duplicate value from app and category column

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7083 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             7083 non-null   object
#  1   Category        7083 non-null   object
#  2   Rating          7083 non-null   float64
#  3   Reviews         7083 non-null   object
#  4   Size            7083 non-null   float64
#  5   Installs        7083 non-null   int64
#  6   Type            7083 non-null   object
#  7   Price           7083 non-null   object
#  8   Content Rating  7083 non-null   object
#  9   Genres          7083 non-null   object
#  10  Last Updated    7083 non-null   object
#  11  Current Ver     7083 non-null   object
#  12  Android Ver     7083 non-null   object
#  13  Log_installs    7083 non-null   float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 830.0+ KB

# %% [markdown]
# # **Lets check max rating in boxplot**

# %%
play_store.boxplot(column='Rating');

# %% [markdown]
# # There is an outlier

# %%
play_store['Rating'].max()
# Out:
# 5.0

# %%
play_store.hist(column='Rating',edgecolor='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f489910eb10>]],
#       dtype=object)

# %% [markdown]
# # **TOP 20 Apps according to Genres**

# %%
#What are the top 20 apps present in the google play store as per their Genres?
top_genres = play_store.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
top_genres.head(5)
# Out:
#             Genres  Count
# 0            Tools    627
# 1    Entertainment    425
# 2        Education    399
# 3           Action    276
# 4  Personalization    274

# %%
genres_installs = play_store.groupby(['Genres'])[['Installs']].sum()

# %%
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.head(20)

# %%
top_20_genres_installs.head()
# Out:
#             Genres  Count    Installs
# 0            Tools    627  2890553500
# 1    Entertainment    425  1553869820
# 2        Education    399   218445210
# 3           Action    276  3025937470
# 4  Personalization    274   895131930

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #  TOP 20 Genres according to Installs

# %%
#Which are the Genres that are getting installed the most in top 20 Genres?
plt.figure(figsize=(9,6))
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Installs")
plt.title("Installs according to Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Installs)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# As we can see from the above two plots: Maxinum number of apps present in google play store comes under Tools, Entertainment and Education Genres but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Communication, Tools and Productivity Genres.

# %% [markdown]
# # **Average rating**

# %%
genres_ratings_play_store_data = play_store.groupby(['Genres'])[['Rating']].mean()
genres_ratings_play_store_data
# Out:
#                                          Rating
# Genres
# Action                                 4.234783
# Action;Action & Adventure              4.300000
# Adventure                              4.176119
# Adventure;Action & Adventure           4.333333
# Adventure;Brain Games                  4.600000
# ...                                         ...
# Video Players & Editors                4.021429
# Video Players & Editors;Creativity     4.100000
# Video Players & Editors;Music & Video  4.000000
# Weather                                4.242000
# Word                                   4.342105
#
# [112 rows x 1 columns]

# %%
#lets check genres install rating through merge the top genres install data and avf of genres rating data

genres_installs_ratings = pd.merge(top_genres_installs, genres_ratings_play_store_data , on='Genres')
genres_installs_ratings
# Out:
#                      Genres  Count    Installs    Rating
# 0                     Tools    627  2890553500  4.007177
# 1             Entertainment    425  1553869820  4.086588
# 2                 Education    399   218445210  4.296742
# 3                    Action    276  3025937470  4.234783
# 4           Personalization    274   895131930  4.324453
# ..                      ...    ...         ...       ...
# 107        Card;Brain Games      1      100000  4.400000
# 108  Lifestyle;Pretend Play      1    10000000  4.000000
# 109   Education;Brain Games      1     1000000  4.400000
# 110       Comics;Creativity      1       50000  4.800000
# 111     Strategy;Creativity      1     1000000  4.400000
#
# [112 rows x 4 columns]

# %%
#lets check the kdeplot check the rating avg
plt.figure(figsize=(14,7))
g = sns.kdeplot(genres_installs_ratings.Rating, color="Red", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
plt.show()

# %% [markdown]
# Most of the rating is in between 4.0 to 4.5
# There are very few applications which got rating 5.0

# %% [markdown]
# # **Size is impacting no of Installs**

# %%
# How does size impact on the number of installs of any application?
plt.figure(figsize=(14,7))
sns.scatterplot(play_store['Size'], play_store['Log_installs'], hue = play_store['Type'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# it is clear from the above mentioned plot that size may impact the number of installations. Bulky applications are less installed by the user.

# %% [markdown]
# # **Histogram of size**

# %%
# to remove null values from size column
play_store.loc[ play_store['Size'].isnull(),'Size']=0

# %%
plt.title("Distribution of Size")
plt.hist(play_store['Size'], rwidth=0.9)
plt.xlabel("Size",fontsize = 19)
plt.ylabel("Count",fontsize = 19)
plt.show()

# %% [markdown]
# From the above histogram, it can be concluded that maximum number of applications present in the dataset are of small size.

# %% [markdown]
# # **CORRELATION**
# check Correlation of play store data

# %%
plt.subplots(figsize =(9, 8))
sns.heatmap(play_store.corr(),linewidths = 0.1,annot = True,cmap ="Blues")

# %% [markdown]
# Their are install and Size highly pos correlated data

# %% [markdown]
# # **2 User review Data**

# %%
#The Head is show the first 5 row on the dataset
user_review.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#The tail is show the last 5 row on the dataset
user_review.tail(5)
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
#concate head and tail data
pd.concat([user_review.head(5),user_review.tail(5)])
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# ...

# %%
# The info shows the non null valu counts,data type and shape of the data in dataset
user_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# In User review dataset 64295  rows and 5 column

# %%
#user review data column name
user_review.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
#lets print shape of dataset
print(f"the User review dataset shape is{user_review.shape}")
# Out:
# the User review dataset shape is(64295, 5)

# %%
#CHeck Nan Values
user_review.isnull().sum().to_frame()
# Out:
#                             0
# App                         0
# Translated_Review       26868
# Sentiment               26863
# Sentiment_Polarity      26863
# Sentiment_Subjectivity  26863

# %%
# check mising nan value
user_review[user_review.isnull().any(axis=1)]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %%
#percentage of value missing
print(f'{round((100*26868/64295),3)}% values are missing')
# Out:
# 41.789% values are missing

# %% [markdown]
# # **Remove nan containing row**

# %%
user_review.dropna(subset=['Translated_Review', 'Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity'] , inplace = True) 
user_review.shape
# Out:
# (37427, 5)

# %%
#check nan value again
user_review.isnull().sum().to_frame()
# Out:
#                         0
# App                     0
# Translated_Review       0
# Sentiment               0
# Sentiment_Polarity      0
# Sentiment_Subjectivity  0

# %% [markdown]
# Now we don't have any NaN values in our dataset.

# %% [markdown]
# # **Merge Tow Dataset**

# %%
merge_data=play_store.merge(user_review, on="App")
merge_data.head(3)
# Out:
#                    App        Category  Rating Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14.0    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14.0    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14.0    500000  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  Log_installs  \
# 0       2.0.0  4.0.3 and up     18.931569
# 1       2.0.0  4.0.3 and up     18.931569
# 2       2.0.0  4.0.3 and up     18.931569
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# 1                                         It bad >:(  Negative
# ...

# %%
#What is the distribution of type of reviews in the dataset

catewise_wise_total_review_count = merge_data.groupby(['Category']).size().reset_index(name='Total Sentiment Count')
catewise_wise_total_review_count.sort_values('Total Sentiment Count' , ascending  = False).head(4)
# Out:
#               Category  Total Sentiment Count
# 14                GAME                   5029
# 11              FAMILY                   3396
# 15  HEALTH_AND_FITNESS                   1582
# 7               DATING                   1500

# %%
category_sentiment = merge_data.groupby(['Category','Sentiment']).size().reset_index(name='Sentiment Count')
category_sentiment
# Out:
#              Category Sentiment  Sentiment Count
# 0      ART_AND_DESIGN  Negative               58
# 1      ART_AND_DESIGN   Neutral               54
# 2      ART_AND_DESIGN  Positive              233
# 3   AUTO_AND_VEHICLES  Negative               11
# 4   AUTO_AND_VEHICLES   Neutral               20
# ..                ...       ...              ...
# 93      VIDEO_PLAYERS   Neutral               38
# 94      VIDEO_PLAYERS  Positive              123
# 95            WEATHER  Negative                9
# 96            WEATHER   Neutral               17
# 97            WEATHER  Positive               83
#
# [98 rows x 3 columns]

# %%
category_sentiment['Log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90,fontsize=9)

plt.title("Number of log sentiment count according to Category")
sns.barplot('Category', 'Log_sentiment_count', hue='Sentiment', data=category_sentiment);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Majority of the genres have high positive sentiments, when compared to neutral and negative ones.

# %% [markdown]
# # **Histogram of subjectivity**

# %%
plt.figure(figsize=(18,9))
plt.xlabel("Subjectivity")
plt.title("Distribution of Subjectivity")
plt.hist(merge_data[merge_data['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'],rwidth=0.9)
plt.show()

# %% [markdown]
# It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that maximum number of users give reviews to the applications, according to their experience.

# %% [markdown]
# ##  Percentage of Review Sentimets

# %%
counts = list(merge_data['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentimets', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# # **Correlation merged data frame**

# %%
plt.subplots(figsize =(9, 8))
sns.heatmap(merge_data.corr(),linewidths = 0.1,annot = True,cmap ="Blues")

# %% [markdown]
# We can determine from above that each column  are Positively Correlated.

# %% [markdown]
# # **Conclusion**
#
# * maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this
# we can conclude that maximum number of users give reviews to the applications, according to their experience.
# *    install and rating highly pos correlated datat
# *  Most of the rating is in between 4.0 to 4.5
# *   in merge tow dataframe We can determine from above that each column are Positively Correlated.
# *   Majority of the genres have high positive sentiments, when compared to neutral and negative ones.
# *   Size of maximum number of applications present in the dataset
# *   size is impact the number of installations
